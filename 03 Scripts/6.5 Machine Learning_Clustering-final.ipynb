# %% [markdown]
# ## 6.5 Machine Learning Part 2 - K-means Clustering

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing libraries and data and renaming columns
# #### 2. The elbow technique
# #### 3. k-means clustering
# #### 4. Standardization

# %% [markdown]
# ### Importing libraries and data and renaming columns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# This option ensures the graphs you create are displayed in your notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
path = r"C:\Users\fardi\OneDrive\Desktop\CF\Data Immersion\A6.Advanced Analytics & Dashboard Design\05-12-2021 Germany Apartment Rental"

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'immo_data_clean.csv'), index_col=[0])

# %%
df.shape
# Out:
# (144591, 24)

# %%
df.head()
# Out:
#     serviceCharge                     heatingType  newlyConst  balcony  \
# 0           245.0                 central_heating       False    False
# 2           255.0                   floor_heating        True     True
# 4           138.0  self_contained_central_heating       False     True
# 8           110.0                     oil_heating       False    False
# 10           88.0                 central_heating       False     True
#
#     totalRent  yearConstructed  hasKitchen              geo_bln  cellar  \
# 0       840.0           1965.0       False  Nordrhein_Westfalen    True
# 2      1300.0           2019.0       False              Sachsen    True
# 4       903.0           1950.0       False               Bremen   False
# 8       690.0           1970.0        True   Baden_WÃ¼rttemberg    True
# 10      307.0           1930.0       False              Sachsen    True
#
#     baseRent  ...  petsAllowed                       street   lift  \
# 0      595.0  ...           no   Sch&uuml;ruferstra&szlig;e  False
# 2      965.0  ...           no                    Turnerweg   True
# 4      765.0  ...           no  Hermann-Henrich-Meier-Allee  False
# 8      580.0  ...           no               no_information  False
# 10     219.0  ...           no           Hofer Stra&szlig;e  False
#
#       typeOfFlat noRooms floor  numberOfFloors garden  \
# 0   ground_floor     4.0   1.0        3.000000   True
# 2      apartment     3.0   3.0        4.000000  False
# 4      apartment     3.0   1.0        3.670219  False
# 8    roof_storey     2.0   2.0        2.000000  False
# 10     apartment     2.0   3.0        3.670219  False
#
#                           regio3   date
# 0                       SchÃ¼ren  43586
# 2   ÃuÃere_Neustadt_Antonstadt  43739
# 4              Neu_Schwachhausen  43862
# 8                     Denzlingen  43862
# 10                    Sonnenberg  43739
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144591 entries, 0 to 268847
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   serviceCharge    144591 non-null  float64
#  1   heatingType      144591 non-null  object
#  2   newlyConst       144591 non-null  bool
#  3   balcony          144591 non-null  bool
#  4   totalRent        144591 non-null  float64
#  5   yearConstructed  144591 non-null  float64
#  6   hasKitchen       144591 non-null  bool
#  7   geo_bln          144591 non-null  object
#  8   cellar           144591 non-null  bool
#  9   baseRent         144591 non-null  float64
#  10  livingSpace      144591 non-null  float64
#  11  geo_krs          144591 non-null  object
#  12  condition        144591 non-null  object
#  13  interiorQual     144591 non-null  object
#  14  petsAllowed      144591 non-null  object
#  15  street           144591 non-null  object
#  16  lift             144591 non-null  bool
#  17  typeOfFlat       144591 non-null  object
#  18  noRooms          144591 non-null  float64
#  19  floor            144591 non-null  float64
#  20  numberOfFloors   144591 non-null  float64
#  21  garden           144591 non-null  bool
#  22  regio3           144591 non-null  object
#  23  date             144591 non-null  int64
# dtypes: bool(6), float64(8), int64(1), object(9)
# memory usage: 21.8+ MB

# %%
#### Drop column 'date'
df = df.drop(['date' ], axis=1)

# %%
# numerical variables
columns = []
for cols in df.columns:
    if df[cols].dtype == 'int64' or df[cols].dtype == 'float64':
        columns.append(cols)
        
columns
# Out:
# ['serviceCharge',
#  'totalRent',
#  'yearConstructed',
#  'baseRent',
#  'livingSpace',
#  'noRooms',
#  'floor',
#  'numberOfFloors']

# %%
df = df[['serviceCharge',
 'totalRent',
 'yearConstructed',
 'baseRent',
 'livingSpace',
 'noRooms',
 'floor',
 'numberOfFloors']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144591 entries, 0 to 268847
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   serviceCharge    144591 non-null  float64
#  1   totalRent        144591 non-null  float64
#  2   yearConstructed  144591 non-null  float64
#  3   baseRent         144591 non-null  float64
#  4   livingSpace      144591 non-null  float64
#  5   noRooms          144591 non-null  float64
#  6   floor            144591 non-null  float64
#  7   numberOfFloors   144591 non-null  float64
# dtypes: float64(8)
# memory usage: 9.9 MB

# %% [markdown]
# ### 2. The elbow technique

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(df).score(df) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# [-101426530903.51624,
#  -55079781480.27917,
#  -33801526354.727303,
#  -19783811994.570473,
#  -13147599462.2527,
#  -9789093377.41075,
#  -7782943374.091781,
#  -6527907547.907618,
#  -5669067741.371605]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# #####  In this example, there's a large jump from two to three  and 4 on the x-axis, I have tried to use 2,3 and 4 clusters, the 2 clusters works better

# %% [markdown]
# ### 3. k-means clustering

# %%
# Create the k-means object.

# kmeans = KMeans(n_clusters = 3, n_jobs = -1)  
# n_jobs does not work
kmeans = KMeans(n_clusters = 2, n_init=10)

# %%
# Fit the k-means object to the data.

kmeans.fit(df)
# Out:
# KMeans(n_clusters=2)

# %%
df['clusters'] = kmeans.fit_predict(df)

# %%
df.head()
# Out:
#     serviceCharge  totalRent  yearConstructed  baseRent  livingSpace  noRooms  \
# 0           245.0      840.0           1965.0     595.0        86.00      4.0
# 2           255.0     1300.0           2019.0     965.0        83.80      3.0
# 4           138.0      903.0           1950.0     765.0        84.97      3.0
# 8           110.0      690.0           1970.0     580.0        53.00      2.0
# 10           88.0      307.0           1930.0     219.0        40.20      2.0
#
#     floor  numberOfFloors  clusters
# 0     1.0        3.000000         0
# 2     3.0        4.000000         1
# 4     1.0        3.670219         0
# 8     2.0        2.000000         0
# 10    3.0        3.670219         0

# %%
df['clusters'].value_counts()
# Out:
# 0    119265
# 1     25326
# Name: clusters, dtype: int64

# %%
# Plot the clusters for the "livingSpace" and "totalRent" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df['livingSpace'], y=df['totalRent'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('livingSpace') # Label x-axis.
plt.ylabel('totalrent') # Label y-axis.
plt.show()

# %%
# Plot the clusters for the "noRoomse" and "totalRent" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df['noRooms'], y=df['totalRent'], hue=kmeans.labels_, s=100)

ax.grid(False) 
plt.xlabel('noRooms') 
plt.ylabel('totalRent') 
plt.show()

# %%
# df.loc[df['clusters'] == 2, 'cluster'] = 'dark purple'
df.loc[df['clusters'] == 1, 'cluster'] = 'orange'
df.loc[df['clusters'] == 0, 'cluster'] = 'blue'

# %%
df.groupby('cluster').agg({'livingSpace':['mean', 'median'], 
                         'noRooms':['mean', 'median'], 
                         'numberOfFloors':['mean', 'median'],
                          'totalRent':['mean', 'median']})
# Out:
#         livingSpace          noRooms        numberOfFloors            \
#                mean  median     mean median           mean    median
# cluster
# blue      64.306117   62.38  2.46982    2.1       3.646744  3.670219
# orange   109.851839  105.00  3.36162    3.0       3.780768  3.670219
#
#            totalRent
#                 mean  median
# cluster
# blue      619.055737   570.0
# orange   1726.425179  1525.0

# %% [markdown]
# - Cluster orange has higher mean totalRent, higher mean livingSpace and higher noRooms
# - numberOfFloor seems to be almost similar

# %% [markdown]
# ## 4. Standardization

# %%
# load data
df_new = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'immo_data_clean.csv'), index_col=[0])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144591 entries, 0 to 268847
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   serviceCharge    144591 non-null  float64
#  1   heatingType      144591 non-null  object
#  2   newlyConst       144591 non-null  bool
#  3   balcony          144591 non-null  bool
#  4   totalRent        144591 non-null  float64
#  5   yearConstructed  144591 non-null  float64
#  6   hasKitchen       144591 non-null  bool
#  7   geo_bln          144591 non-null  object
#  8   cellar           144591 non-null  bool
#  9   baseRent         144591 non-null  float64
#  10  livingSpace      144591 non-null  float64
#  11  geo_krs          144591 non-null  object
#  12  condition        144591 non-null  object
#  13  interiorQual     144591 non-null  object
#  14  petsAllowed      144591 non-null  object
#  15  street           144591 non-null  object
#  16  lift             144591 non-null  bool
#  17  typeOfFlat       144591 non-null  object
#  18  noRooms          144591 non-null  float64
#  19  floor            144591 non-null  float64
#  20  numberOfFloors   144591 non-null  float64
#  21  garden           144591 non-null  bool
#  22  regio3           144591 non-null  object
#  23  date             144591 non-null  int64
# dtypes: bool(6), float64(8), int64(1), object(9)
# memory usage: 21.8+ MB

# %%
df = (df_new-df_new.mean())/df_new.std()
# Out:
# C:\Users\fardi\AppData\Local\Temp/ipykernel_18548/3999781979.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = (df_new-df_new.mean())/df_new.std()
# C:\Users\fardi\AppData\Local\Temp/ipykernel_18548/3999781979.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = (df_new-df_new.mean())/df_new.std()

# %%
df = df[['serviceCharge',
 'totalRent',
 'yearConstructed',
 'baseRent',
 'livingSpace',
 'noRooms',
 'floor',
 'numberOfFloors']]

# %% [markdown]
# #### Nornmalize the data

# %%
# # normalise data (found this code online )
# for cols in df.columns:
#     if df[cols].dtype == 'int64' or df[cols].dtype == 'float64':
#         if cols != 'livingSpace':
#             df[cols] = ((df[cols] - df[cols].mean())/(df[cols].std()))

# %%
df.head()
# Out:
#     serviceCharge  totalRent  yearConstructed  baseRent  livingSpace  \
# 0        0.233809   0.049494        -0.131913 -0.091034     0.461482
# 2        0.258809   0.893305         1.383901  0.660926     0.387463
# 4       -0.033693   0.165060        -0.552972  0.254461     0.426828
# 8       -0.103693  -0.225661         0.008441 -0.121519    -0.648798
# 10      -0.158694  -0.928225        -1.114385 -0.855188    -1.079453
#
#      noRooms     floor  numberOfFloors
# 0   1.454690 -0.661930   -1.284835e-01
# 2   0.395945  0.490852    6.322030e-02
# 4   0.395945 -0.661930    4.098331e-13
# 8  -0.662800 -0.085539   -3.201873e-01
# 10 -0.662800  0.490852    4.098331e-13

# %% [markdown]
# #### The elbow technique

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
# Creates a score that represents 
score = [kmeans[i].fit(df).score(df) for i in range(len(kmeans))]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve for Normalized Data')
pl.show()

# %% [markdown]
# Here we see that the optimal number of cluster is 3

# %%
# Create the k-means object.
kmeans = KMeans(n_clusters = 4 , n_init=10)

# %%
# Fit the k-means object to the data.

kmeans.fit(df)
# Out:
# KMeans(n_clusters=4)

# %%
df['clusters'] = kmeans.fit_predict(df)

# %%
df.head()
# Out:
#     serviceCharge  totalRent  yearConstructed  baseRent  livingSpace  \
# 0        0.233809   0.049494        -0.131913 -0.091034     0.461482
# 2        0.258809   0.893305         1.383901  0.660926     0.387463
# 4       -0.033693   0.165060        -0.552972  0.254461     0.426828
# 8       -0.103693  -0.225661         0.008441 -0.121519    -0.648798
# 10      -0.158694  -0.928225        -1.114385 -0.855188    -1.079453
#
#      noRooms     floor  numberOfFloors  clusters
# 0   1.454690 -0.661930   -1.284835e-01         1
# 2   0.395945  0.490852    6.322030e-02         1
# 4   0.395945 -0.661930    4.098331e-13         1
# 8  -0.662800 -0.085539   -3.201873e-01         3
# 10 -0.662800  0.490852    4.098331e-13         0

# %%
df['clusters'].value_counts()
# Out:
# 3    55435
# 0    41209
# 1    39798
# 2     8149
# Name: clusters, dtype: int64

# %%
# Plot the clusters for the "livingSpace" and "totalRent" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df['livingSpace'], y=df['totalRent'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('livingSpace') # Label x-axis.
plt.ylabel('totalrent') # Label y-axis.
plt.show()

# %%
df.loc[df['clusters'] == 3, 'cluster'] = 'dark blue'
df.loc[df['clusters'] == 2, 'cluster'] = 'dark purple'
df.loc[df['clusters'] == 1, 'cluster'] = 'purple'
df.loc[df['clusters'] == 0, 'cluster'] = 'pink'

# %%
# df = df.drop(['cluster'], axis=1)

# %%
df.groupby('cluster').agg({'livingSpace':['mean', 'median'], 
                         'noRooms':['mean', 'median'], 
                         'numberOfFloors':['mean', 'median'],
                         'serviceCharge':['mean', 'median'],
                         'yearConstructed':['mean', 'median'],
                          'totalRent':['mean', 'median']})
# Out:
#             livingSpace             noRooms           numberOfFloors  \
#                    mean    median      mean    median           mean
# cluster
# dark blue     -0.605346 -0.527677 -0.579492 -0.662800       0.088463
# dark purple    2.355349  2.144398  1.446505  1.454690       0.075531
# pink          -0.312194 -0.345995 -0.151409 -0.133427      -0.059869
# purple         0.684175  0.592697  0.667772  0.395945      -0.076696
#
#                           serviceCharge           yearConstructed            \
#                    median          mean    median            mean    median
# cluster
# dark blue    4.098331e-13     -0.092908 -0.103693        0.393372  0.345288
# dark purple  4.098331e-13      0.475881  0.371310        0.405367  1.075125
# pink         4.098331e-13     -0.069893 -0.078693       -1.139216 -1.198597
# purple      -1.284835e-01      0.104342  0.103808        0.548671  0.710206
#
#             totalRent
#                  mean    median
# cluster
# dark blue   -0.477008 -0.566854
# dark purple  2.832225  2.397488
# pink        -0.443541 -0.519160
# purple       0.543771  0.489743

# %% [markdown]
# ##### Standardizing the data still got the same outcome as before just the color has changed. Blue cluster has higher totalRent, higher livingSpace and noRooms but lower numberOfFloors

# %%
df.tail()
# Out:
#         serviceCharge  totalRent  yearConstructed  baseRent  livingSpace  \
# 268840      -0.098368   1.222831         1.299690  1.251072     0.584959
# 268841      -0.133694  -0.712650         0.682136 -0.685448    -0.511527
# 268843      -0.078693  -0.816328        -1.114385 -0.796250    -0.581509
# 268846       0.171308   0.618149         0.373359  0.589794     1.437183
# 268847       0.171308   0.214588        -0.131913  0.020744     0.764286
#
#          noRooms     floor  numberOfFloors  clusters    cluster
# 268840  0.395945 -0.085539    6.322030e-02         1     purple
# 268841 -0.133427 -0.085539    4.098331e-13         3  dark blue
# 268843 -0.662800 -0.661930    6.322030e-02         0       pink
# 268846  0.925318 -0.661930   -5.118911e-01         1     purple
# 268847  1.454690 -0.661930   -3.201873e-01         1     purple

# %%
# save cluster data
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'immo_data_cluster.csv'))

# %%
df_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'immo_data_clean.csv'))

# %%
df_cluster = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'immo_data_cluster.csv'))

# %%
df_merge.head()
# Out:
# Empty DataFrame
# Columns: [serviceCharge, heatingType, newlyConst, balcony, totalRent, yearConstructed, hasKitchen, geo_bln, cellar, baseRent, livingSpace, geo_krs, condition, interiorQual, petsAllowed, street, lift, typeOfFlat, noRooms, floor, numberOfFloors, garden, regio3, date, clusters, cluster]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_clean.shape
# Out:
# (144591, 25)

# %%
df_cluster.shape
# Out:
# (144591, 11)

# %%
df_cluster.head()
# Out:
#    Unnamed: 0  serviceCharge  totalRent  yearConstructed  baseRent  \
# 0           0       0.233809   0.049494        -0.131913 -0.091034
# 1           2       0.258809   0.893305         1.383901  0.660926
# 2           4      -0.033693   0.165060        -0.552972  0.254461
# 3           8      -0.103693  -0.225661         0.008441 -0.121519
# 4          10      -0.158694  -0.928225        -1.114385 -0.855188
#
#    livingSpace   noRooms     floor  numberOfFloors  clusters    cluster
# 0     0.461482  1.454690 -0.661930   -1.284835e-01         1     purple
# 1     0.387463  0.395945  0.490852    6.322030e-02         1     purple
# 2     0.426828  0.395945 -0.661930    4.098331e-13         1     purple
# 3    -0.648798 -0.662800 -0.085539   -3.201873e-01         3  dark blue
# 4    -1.079453 -0.662800  0.490852    4.098331e-13         0       pink

# %%
df_cluster = df_cluster.drop(['serviceCharge', 'totalRent', 'yearConstructed', 'baseRent', 'livingSpace', 'noRooms', 'floor', 'numberOfFloors'], axis=1)

# %%
df_cluster.head()
# Out:
#    Unnamed: 0  clusters    cluster
# 0           0         1     purple
# 1           2         1     purple
# 2           4         1     purple
# 3           8         3  dark blue
# 4          10         0       pink

# %%
df_clean.head()
# Out:
#    Unnamed: 0  serviceCharge                     heatingType  newlyConst  \
# 0           0          245.0                 central_heating       False
# 1           2          255.0                   floor_heating        True
# 2           4          138.0  self_contained_central_heating       False
# 3           8          110.0                     oil_heating       False
# 4          10           88.0                 central_heating       False
#
#    balcony  totalRent  yearConstructed  hasKitchen              geo_bln  \
# 0    False      840.0           1965.0       False  Nordrhein_Westfalen
# 1     True     1300.0           2019.0       False              Sachsen
# 2     True      903.0           1950.0       False               Bremen
# 3    False      690.0           1970.0        True   Baden_WÃ¼rttemberg
# 4     True      307.0           1930.0       False              Sachsen
#
#    cellar  ...  petsAllowed                       street   lift    typeOfFlat  \
# 0    True  ...           no   Sch&uuml;ruferstra&szlig;e  False  ground_floor
# 1    True  ...           no                    Turnerweg   True     apartment
# 2   False  ...           no  Hermann-Henrich-Meier-Allee  False     apartment
# 3    True  ...           no               no_information  False   roof_storey
# 4    True  ...           no           Hofer Stra&szlig;e  False     apartment
#
#   noRooms floor numberOfFloors  garden                        regio3   date
# 0     4.0   1.0       3.000000    True                      SchÃ¼ren  43586
# 1     3.0   3.0       4.000000   False  ÃuÃere_Neustadt_Antonstadt  43739
# 2     3.0   1.0       3.670219   False             Neu_Schwachhausen  43862
# 3     2.0   2.0       2.000000   False                    Denzlingen  43862
# 4     2.0   3.0       3.670219   False                    Sonnenberg  43739
#
# [5 rows x 25 columns]

# %%
df_merge = pd.merge(df_clean, df_cluster, left_index=True, right_index=True)

# %%
df_merge.head()
# Out:
#    serviceCharge                     heatingType  newlyConst  balcony  \
# 0          245.0                 central_heating       False    False
# 1          255.0                   floor_heating        True     True
# 2          138.0  self_contained_central_heating       False     True
# 3          110.0                     oil_heating       False    False
# 4           88.0                 central_heating       False     True
#
#    totalRent  yearConstructed  hasKitchen              geo_bln  cellar  \
# 0      840.0           1965.0       False  Nordrhein_Westfalen    True
# 1     1300.0           2019.0       False              Sachsen    True
# 2      903.0           1950.0       False               Bremen   False
# 3      690.0           1970.0        True   Baden_WÃ¼rttemberg    True
# 4      307.0           1930.0       False              Sachsen    True
#
#    baseRent  ...   lift    typeOfFlat noRooms floor numberOfFloors garden  \
# 0     595.0  ...  False  ground_floor     4.0   1.0       3.000000   True
# 1     965.0  ...   True     apartment     3.0   3.0       4.000000  False
# 2     765.0  ...  False     apartment     3.0   1.0       3.670219  False
# 3     580.0  ...  False   roof_storey     2.0   2.0       2.000000  False
# 4     219.0  ...  False     apartment     2.0   3.0       3.670219  False
#
#                          regio3   date  clusters    cluster
# 0                      SchÃ¼ren  43586         1     purple
# 1  ÃuÃere_Neustadt_Antonstadt  43739         1     purple
# 2             Neu_Schwachhausen  43862         1     purple
# 3                    Denzlingen  43862         3  dark blue
# 4                    Sonnenberg  43739         0       pink
#
# [5 rows x 26 columns]

# %%
df_merge.columns
# Out:
# Index(['Unnamed: 0_x', 'serviceCharge', 'heatingType', 'newlyConst', 'balcony',
#        'totalRent', 'yearConstructed', 'hasKitchen', 'geo_bln', 'cellar',
#        'baseRent', 'livingSpace', 'geo_krs', 'condition', 'interiorQual',
#        'petsAllowed', 'street', 'lift', 'typeOfFlat', 'noRooms', 'floor',
#        'numberOfFloors', 'garden', 'regio3', 'date', 'Unnamed: 0_y',
#        'clusters', 'cluster'],
#       dtype='object')

# %%
df_merge= df_merge.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)

# %%
df_merge.to_csv(os.path.join(path, '02 Data','Prepared Data', 'immo_data_complete.csv'))
